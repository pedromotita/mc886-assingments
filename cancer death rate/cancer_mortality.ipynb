# %% [markdown]
# # **Assignment \#2**: Machine Learning MC886/MO444
# University of Campinas (UNICAMP), Institute of Computing (IC)
#
# Prof. Sandra Avila, 2021s2

# %%
# TODO: RA & Name 
print('185853: ' + 'Pedro R. S. Mota')
print('206956: ' + 'Vitor Coppo Ferreira')
# Out:
# 185853: Pedro R. S. Mota
# 206956: Vitor Coppo Ferreira

# %% [markdown]
# ## Objective: Predict cancer mortality rates for US counties.
#
# Explore **linear regression** alternatives and come up with the best possible model to the problems, avoiding overfitting. In particular, predict the **TARGET_deathRate** from their attributes.

# %% [markdown]
# ## Dataset
#
# These data were aggregated from a number of sources including the American Community Survey (census.gov), clinicaltrials.gov, and cancer.gov.
#
# The dataset contains the death rate and attributes of 3,047 counties.
#
# Dataset Information: You should respect the following traininig/test split: 2042 training examples, and 305 test examples.
#
# There are 33 attributes as follows:
#
# Data Dictionary
#
# - 1: **avgAnnCount**: Mean number of reported cases of cancer diagnosed annually (a)
#
# - 2: **avgDeathsPerYear**: Mean number of reported mortalities due to cancer (a)
#
# - 3: **incidenceRate**: Mean per capita (100,000) cancer diagoses(a)
#
# - 4: **medianIncome**: Median income per county (b)
#
# - 5: **popEst2015**: Population of county (b)
#
# - 6: **povertyPercent**: Percent of populace in poverty (b)
#
# - 7: **studyPerCap**: Per capita number of cancer-related clinical trials per county (a)
#
# - 8: **binnedInc**: Median income per capita binned by decile (b)
#
# - 9: **MedianAge**: Median age of county residents (b)
#
# - 10: **MedianAgeMale**: Median age of male county residents (b)
#
# - 11: **MedianAgeFemale**: Median age of female county residents (b)
#
# - 12: **Geography**: County name (b)
#
# - 13: **AvgHouseholdSize**: Mean household size of county (b)
#
# - 14: **PercentMarried**: Percent of county residents who are married (b)
#
# - 15: **PctNoHS18_24**: Percent of county residents ages 18-24 highest education attained: less than high school (b)
#
# - 16: **PctHS18_24**: Percent of county residents ages 18-24 highest education attained: high school diploma (b)
#
# - 17: **PctSomeCol18_24**: Percent of county residents ages 18-24 highest education attained: some college (b)
#
# - 18: **PctBachDeg18_24**: Percent of county residents ages 18-24 highest education attained: bachelor's degree (b)
#
# - 19: **PctHS25_Over**: Percent of county residents ages 25 and over highest education attained: high school diploma (b)
#
# - 20: **PctBachDeg25_Over**: Percent of county residents ages 25 and over highest education attained: bachelor's degree (b)
#
# - 21: **PctEmployed16_Over**: Percent of county residents ages 16 and over employed (b)
#
# - 22: **PctUnemployed16_Over**: Percent of county residents ages 16 and over unemployed (b)
#
# - 23: **PctPrivateCoverage**: Percent of county residents with private health coverage (b)
#
# - 24: **PctPrivateCoverageAlone**: Percent of county residents with private health coverage alone (no public assistance) (b)
#
# - 25: **PctEmpPrivCoverage**: Percent of county residents with employee-provided private health coverage (b)
#
# - 26: **PctPublicCoverage**: Percent of county residents with government-provided health coverage (b)
#
# - 27: **PctPubliceCoverageAlone**: Percent of county residents with government-provided health coverage alone (b)
#
# - 28: **PctWhite**: Percent of county residents who identify as White (b)
#
# - 29: **PctBlack**: Percent of county residents who identify as Black (b)
#
# - 30: **PctAsian**: Percent of county residents who identify as Asian (b)
#
# - 31: **PctOtherRace**: Percent of county residents who identify in a category which is not White, Black, or Asian (b)
#
# - 32: **PctMarriedHouseholds**: Percent of married households (b)
#
# - 33: **BirthRate**: Number of live births relative to number of women in county (b)
#
# - **TARGET_deathRate**: Dependent variable. Mean per capita (100,000) cancer mortalities (a)
#
# (a): years 2010-2016
#
# (b): 2013 Census Estimates
#
#
# The data is available at
# - train: https://tinyurl.com/53zvz9t7
# - test: https://tinyurl.com/phs3bkbt

# %% [markdown]
# ## Activities
#
# 1. (5 points) Perform Linear Regression. You should implement your solution and compare it with ```sklearn.linear_model.SGDRegressor``` (linear model fitted by minimizing a regularized empirical loss with SGD, http://scikit-learn.org). Keep in mind that friends don't let friends use testing data for training :-)
#
# Note: Some factors to consider: Are there any outliers? Are there missing values? How will you handle categorical variables?

# %% [markdown]
# ## 1.1 Processamento dos dados

# %%
# process_data(data_train, data_test):
#     - data_train: dataset de treino
#     - data_test: dataset de teste
# 
#     retorno: datasets de treino e teste com features normalizadas,
#              dados categoricos tratados com onehot enconding e 
#              valores NaN preenchidos

def process_data(data_train, data_test):

    data_train = handle_categorical_values(data_train, ['binnedinc'])
    data_test = handle_categorical_values(data_test, ['binnedinc'])
    
    data_train = handle_missing_values(data_train)
    data_test = handle_missing_values(data_test)
    
    data_train = handle_outliers(data_train)
    data_test = handle_outliers(data_test)

    data_train, data_test = data_train.align(data_test, join='left', fill_value=1, axis=1)
    
    data_train = feature_scaling(data_train)
    data_test = feature_scaling(data_test)
    
    data_train = handle_missing_values(data_train)
    data_test = handle_missing_values(data_test)
    
    target_train = data_train.pop('target_deathrate')
    target_test = data_test.pop('target_deathrate')
    
    data_train.insert(loc=len(data_train.columns), column='target_deathrate', value=target_train)
    data_test.insert(loc=len(data_test.columns), column='target_deathrate', value=target_test)
    
    return data_train, data_test

# feature_scaling(data):
#     - data: dataset a ser normalizado
# 
#     retorno: dataset com features normalizadas entre -0.5 e 0.5


def feature_scaling(data):
    s = data.max() - data.min()
    u = data.min() + s/2
    
    return (data - u)/s

def handle_outliers(data):
    for i in data.keys():
        data = data[np.abs(data[i] - data[i].mean()) <= (3 * data[i].std())]
    print(data.shape)
    # print(data)
    return data
    
# handle_categorical_values(data, categorical_values):
#     - data: dataset
#     - categorical_values: lista com colunas dos valores categoricos
# 
#     retorno: dataset com colunas de valores categoricos tratadas com
#              a técnica onehot encoding

def handle_categorical_values(data, categorical_values):
    return pd.get_dummies(data, columns=categorical_values)


# handle_missing_values(data):
#     - data: dataset
# 
#     retorno: datasets valores NaN substituidos por zero

def handle_missing_values(X):
    m = X.shape[0]
    
    for column in X:
        X[column] = X[column].fillna(value=0)
        
    return X

# process_data(data, train_frac):
#     - data: dataset
#     - train_frac: fração do dataset que deve ser utilizada como teste
# 
#     retorno: dataset passado como parâmetro dividido em treino e validação
#              com as proporções passadas pelo parâmetro train_frac

def train_validation_split(data, train_frac):
    
    train_index = int(train_frac * data.shape[0])
    
    data_train = data.iloc[:train_index, :]
    data_validation = data.iloc[train_index:, :]
    
    return data_train, data_validation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline


df_train = pd.read_csv("./data/data-train.csv")
df_test = pd.read_csv("./data/data-test.csv")

df_train = df_train.drop(labels=["avganncount","geography"], axis=1)
df_test = df_test.drop(labels=["avganncount","geography"], axis=1)

data_train, data_test = process_data(df_train, df_test)

data_train, data_validation = train_validation_split(data_train, train_frac=0.8)
# Out:
# (1748, 41)
# (176, 41)

# %% [markdown]
# ## 1.1 Implementação da regressão linear sem o uso de bibliotecas externas

# %%
# get_batches(data, batch_size):
#     - data: dataset
#     - batch_size: tamanho dos batches
# 
#     retorno: dataset separado em uma lista de batches com tamanho batch_size

def get_batches(data, batch_size):
    
    n=data.shape[0]//batch_size
    
    return np.array_split(data, n)

# get_features_and_target(data):
#     - data_train: dataset
# 
#     retorno: colunas de feature e coluna de variável target separadas

def get_features_and_target(data):

    Y = data[:, -1]
    X = data[:, :-1]
    
    return X, Y

# evaluate_gradient(X, Y, params):
#     - X: matriz com valores das features
#     - Y: matriz com valores esperados
#     - params: matriz com valores dos parâmetros das features
# 
#     retorno: gradiente e função de custo

def evaluate_gradient(X, Y, params):
    m = X.shape[0]

    loss = X.dot(params)
    loss_function = np.sum(np.square(loss))/2

    gradient = X.transpose().dot(loss)/m

    return loss_function, gradient

# stochastic_gradient_descent(data, learning_rate, batch_size, ephocs):
#     - data: dataset a ser utilizado para descida do gradiente
#     - learning_rate: learning a ser utilizado na descida do gradiente
#     - batch_size: tamanho dos batches
#     - epochs: total de epocas a serem feitas
# 
#     retorno: parametros ao final a descida do gradiente, lista com valores
#              da função de custo ao final de cada atualização

def stochastic_gradient_descent(data, learning_rate, batch_size, ephocs):
    
    m = data.shape[0]
    
    # Initialize x_0 = 1
    data = np.c_[np.full(data.shape[0], fill_value=1), data]
    
    # Parameters random initialization
    params = np.random.rand(data.shape[1]-1)
    
    cost = []
    
    for i in range(ephocs):
        for batch in get_batches(data, batch_size):
            X, Y = get_features_and_target(batch)
            
            loss_function, gradient = evaluate_gradient(X, Y, params)
            params = params - learning_rate*gradient
            
            cost.append(loss_function)
        
    return params, cost

# %% [markdown]
# ###  1.1.1 Treinando o modelo

# %%
params, cost = stochastic_gradient_descent(data_train, learning_rate = 0.001, batch_size=10, ephocs=100)

plt.figure(figsize=(10,5))
plt.scatter(np.arange(0,len(cost)), cost)
plt.show()

print(f"Cost after {len(cost)} iterations: {cost[len(cost)-1]}")
# Out:
# Cost after 13900 iterations: 0.3352940753475505

# %% [markdown]
# ### 1.1.2 Validação do modelo treinado

# %%
def predict_values(X, params):

    X = np.c_[np.ones((X.shape[0], 1)), X]
  
    predict_values = X.dot(params)
  
    return predict_values

def mean_squared_error(Y_predicted, Y_expected):
   
    n = Y_predicted.shape[0]
    mse = (np.sum((Y_predicted - Y_expected)**2))/n
    
    return mse

def plot(Y_predicted, Y, title = None):
    
    x_ax = range(len(Y))
    plt.figure(figsize=(10,5))
    plt.scatter(x_ax, Y, label="Valor original")
    plt.scatter(x_ax, Y_predicted, label="Valor previsto")
    plt.ylabel('target_deathrate normalizada')
    if title is not None:
        plt.title(title)    
    plt.legend(loc='best',fancybox=True, shadow=True)
    plt.grid(True)
    plt.show()

# %%
X_validation = data_validation.iloc[:, :-1]
Y_validation = data_validation.iloc[:, -1]

Y_predicted = predict_values(X_validation, params)

mse = mean_squared_error(Y_predicted, Y_validation)

plot(Y_predicted, Y_validation, 'Valores originais, e valores previstos pelo modelo usando dados de validação')

print(f"MSE: {mse}")
# Out:
# MSE: 0.07342348611636126

# %% [markdown]
# ### 1.1.3 Aplicação do modelo treinado usando o conjunto de testes

# %%
X_test = data_test.iloc[:, :-1]
Y_test = data_test.iloc[:, -1]

Y_predicted_test = predict_values(X_test, params)

mse = mean_squared_error(Y_predicted_test, Y_test)

plot(Y_predicted_test, Y_test, 'Valores originais, e valores previstos pelo modelo usando dados de teste')

print(f"MSE: {mse}")
# Out:
# MSE: 0.31944295730531463

# %% [markdown]
# ## 1.2 Regressão linear usando biblioteca sklearn

# %%
from sklearn import linear_model


X_train = data_train.iloc[:, :-1]
Y_train = data_train.iloc[:, -1]

lr = 1e-3

model = linear_model.SGDRegressor(max_iter=1000, eta0=lr)

# %% [markdown]
# ### 1.2.1 Treinando o modelo

# %%
model.fit(X_train, Y_train)
# Out:
# SGDRegressor(eta0=0.001)

# %% [markdown]
# ### 1.2.2 Validação do modelo treinado

# %%
Y_skt_predicted = model.predict(X_validation)

mse = mean_squared_error(Y_skt_predicted, Y_validation)

plot(Y_skt_predicted, Y_validation, 'Valores originais, e valores previstos pelo modelo do skelarn usando dados de validação')

print(f"MSE: {mse}")
# Out:
# MSE: 0.020732034069959184

# %% [markdown]
# ### 1.2.3 Aplicação do modelo treinado usando o conjunto de testes

# %%
Y_skt_predicted = model.predict(X_test)

mse = mean_squared_error(Y_skt_predicted, Y_test)

plot(Y_skt_predicted, Y_test, 'Valores originais, e valores previstos pelo modelo do sklearn usando dados de teste')

print(f"MSE: {mse}")
# Out:
# MSE: 0.039701771159110305

# %% [markdown]
# ### 1.3 Conclusões
#
# Os resultados para a implementação da regressão linear sem bibliotecas externas não foi satisfatório. Apesar dos modelo treinado ter MSE relativamente baixo na etapa de validação, o MSE cresce ao usar fazer previsões usando o conjunto de testes. Colocando em um mesmo gráfico os valores previstos e valores esperados, é possível ver, principalmente ao trabalhar com o conjunto de teste, que o modelo não conseguiu fazer previsões próximas aos valores esperados.
#
# Já usando a função sklearn.linear_model.SGDRegresso teve um desempenho muito melhor. Usando o mesmo learning rate, o modelo da bibioteca sklearn apresentou MSE menores do que o modelo desenvolvido sem bibliotecas externas tanto na etapa de validação quanto de teste.

# %% [markdown]
# 2. (2 points) Use different Gradient Descent (GD) learning rates when optimizing. Compare the GD-based solutions with Normal Equation. What are the conclusions?

# %% [markdown]
# ## 2.1 Sklearn SGD with different learning rates

# %%
from sklearn import linear_model


X_train = data_train.iloc[:, :-1]
Y_train = data_train.iloc[:, -1]

lr_a = 1e-2
lr_b = 1e-4
lr_c = 1e-6

model_a = linear_model.SGDRegressor(max_iter=1000, eta0=lr_a)
model_b = linear_model.SGDRegressor(max_iter=1000, eta0=lr_b)
model_c = linear_model.SGDRegressor(max_iter=1000, eta0=lr_c)

# %%
model_a.fit(X_train, Y_train)
model_b.fit(X_train, Y_train)
model_c.fit(X_train, Y_train)
# Out:
# SGDRegressor(eta0=1e-06)

# %% [markdown]
# ### Modelo A: 0.01 de learning rate

# %%
Y_skt_predicted = model_a.predict(X_validation)

mse = mean_squared_error(Y_skt_predicted, Y_validation)

plot(Y_skt_predicted, Y_validation)

print(f"MSE: {mse}")
# Out:
# MSE: 0.015508119504431239

# %% [markdown]
# ### Modelo B: 0.0001 de learning rate

# %%
Y_skt_predicted = model_b.predict(X_validation)

mse = mean_squared_error(Y_skt_predicted, Y_validation)

plot(Y_skt_predicted, Y_validation)

print(f"MSE: {mse}")
# Out:
# MSE: 0.023186884733574352

# %% [markdown]
# ### Modelo C: 0.000001 de learning rate

# %%
Y_skt_predicted = model_c.predict(X_validation)

mse = mean_squared_error(Y_skt_predicted, Y_validation)

plot(Y_skt_predicted, Y_validation)

print(f"MSE: {mse}")
# Out:
# MSE: 0.023584293425025556

# %% [markdown]
# ## 2.2 Equação normal

# %%
def normal_equation(X, Y):
    X = np.c_[np.ones((X.shape[0], 1)), X] 
  
    params = np.matmul(np.matmul(np.linalg.inv(np.matmul(X.T, X)),X.T),Y)
    return params

# %%
params = normal_equation(X_train, Y_train)

Y_predicted = predict_values(X_validation, params)

mse = mean_squared_error(Y_predicted, Y_validation)

plot(Y_predicted, Y_validation)

print(f"MSE: {mse}")
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /tmp/ipykernel_28673/2413408613.py in <module>
# ----> 1 params = normal_equation(X_train, Y_train)
#       2
#       3 Y_predicted = predict_values(X_validation, params)
#       4
#       5 mse = mean_squared_error(Y_predicted, Y_validation)
#
# /tmp/ipykernel_28673/3326868133.py in normal_equation(X, Y)
#       2     X = np.c_[np.ones((X.shape[0], 1)), X]
#       3
# ----> 4     params = np.matmul(np.matmul(np.linalg.inv(np.matmul(X.T, X)),X.T),Y)
#       5     return params
#
# <__array_function__ internals> in inv(*args, **kwargs)
#
# ~/Documents/Unicamp/MC886-Introducao_a_aprendizado_de_maquina/lib/python3.9/site-packages/numpy/linalg/linalg.py in inv(a)
#     543     signature = 'D->D' if isComplexType(t) else 'd->d'
#     544     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 545     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     546     return wrap(ainv.astype(result_t, copy=False))
#     547
#
# ~/Documents/Unicamp/MC886-Introducao_a_aprendizado_de_maquina/lib/python3.9/site-packages/numpy/linalg/linalg.py in _raise_linalgerror_singular(err, flag)
#      86
#      87 def _raise_linalgerror_singular(err, flag):
# ---> 88     raise LinAlgError("Singular matrix")
#      89
#      90 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix

# %% [markdown]
# ### 2.3 Conclusões
#
# Foram comparados três modelos com learning rates diferentes: A com 0.01, B com 0.0001 e C com 0.000001. O modelo A teve o melhor desempenho, com MSE aproximado 0.0056. Equanto os modelos B e C tiveram MSE aproximado de 00975 e 0.02, respectivamente. Podendo-se concluir que um learning rate menor não resulta necessariamente em um modelo melhor.
#
# As previsão usando a equação normal apresentou um MSE de aproximadamente 112, o pior resultado para todos os modelos testados nesta Tarefa. Portanto, apesar de ter implementação mais simples e direta, ela não é um bom modelo para fazer previsões usando os dados desta tarefa.

# %% [markdown]
# 3. (2 points) Sometimes, we need some more complex function to make good prediction. Devise and evaluate a Polynomial Linear Regression model.

# %% [markdown]
# ## 3.1 Regressão polinomial utilizando bibliotecas externas

# %%
# TODO: Complex model. You can use scikit-learn libraries.
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression

keys = [x for x in data_train.keys() if 'target_deathrate' not in x]
for i in range(2, 5):
    X = np.array(data_train[keys])
    Y = np.array(data_train["target_deathrate"])
    polynomialFeatures = make_pipeline(PolynomialFeatures(i), LinearRegression())
    polynomialFeatures.fit(X, Y)


    X_validation = np.array(data_validation[keys])
    Y_validation = np.array(data_validation["target_deathrate"])

    X_test = np.array(data_test[keys])
    Y_test = np.array(data_test["target_deathrate"])
    m, b = np.polyfit(Y, polynomialFeatures.predict(X), deg=1)
    m_val, b_val = np.polyfit(Y_validation, polynomialFeatures.predict(X_validation), deg=1)
    m_test, b_test = np.polyfit(Y_test, polynomialFeatures.predict(X_test), deg=1)
    r2 = r2_score(Y, polynomialFeatures.predict(X))
    r2_val = r2_score(Y_validation, polynomialFeatures.predict(X_validation))
    r2_test = r2_score(Y_test, polynomialFeatures.predict(X_test))
    print("Degree: " + str(i))
    print("m: " + str(m) + " m_val: " + str(m_val) + " m_test: " + str(m_test))
    print("b: " + str(b) + " b_val: " + str(b_val) + " b_test: " + str(b_test))
    print("r2: " + str(r2) + " r2_val: " + str(r2_val) + " r2_test: " + str(r2_test))
    print("MSE_Validation: " + str(mean_squared_error(polynomialFeatures.predict(X_validation), Y_validation)) + " MSE_test: " + str(mean_squared_error(polynomialFeatures.predict(X_test), Y_test)))
    plt.scatter(Y, polynomialFeatures.predict(X), label="Valor predito")
    plt.scatter(Y_validation, polynomialFeatures.predict(X_validation), label="Valor de Validação")
    plt.scatter(Y_test, polynomialFeatures.predict(X_test), label="Valor de Teste")
    plt.legend(loc='best',fancybox=True, shadow=True)
    plt.grid(True)
    plt.show()
# Out:
# Degree: 2
# m: 0.8614217019051288 m_val: 0.795762825707995 m_test: 82124217105.29071
# b: 0.002415098486050035 b_val: 0.006494790961672979 b_test: 71836426429.45972
# r2: 0.8557866561015439 r2_val: -0.5835330301110409 r2_test: -1.9912282606034495e+23
# MSE_Validation: 0.03732872675696802 MSE_test: 8.447905091806266e+21
# Degree: 3
# m: 1.0000000000000007 m_val: 0.628664620900457 m_test: 0.34374033425785455
# b: 5.831426328816975e-16 b_val: -0.00016243405585845982 b_test: 0.4385657550728203
# r2: 1.0 r2_val: -0.2729329515031327 r2_test: -6.662938541342328
# MSE_Validation: 0.030006930972111944 MSE_test: 0.32510475470042743
# Degree: 4
# m: 0.9999999999999997 m_val: 0.5617200941066329 m_test: 0.47698606375824
# b: 4.319696638443682e-16 b_val: 0.00206873215416412 b_test: 0.2651653522226166
# r2: 1.0 r2_val: -0.18126223690430976 r2_test: -2.2230942420892745
# MSE_Validation: 0.02784597127515159 MSE_test: 0.13674170258544727

# %% [markdown]
# ## 3.2 Conclusões
#
# Rodamos o ajuste polinomial para alguns valores (valores acima de grau 5 precisariaa de muita memória, impossibilitando que o modelo fosse rodado em uma máquina local), e podemos perceber que o erro relativo comparando o o conjunto de treino com o conjunto de teste vai diminuindo  conforme aumentamos o grau, levando a acreditar que a função continuaria melhorando conforme continuassemos a aumentar o grau do polinômio.
#
# No entanto, a quase estabilidade dos valores de teste, com um coeficiente linear no gráfico comparativo de aproximadamente m = 1 a partir o polinômio de terceiro grau levanta suspeitas de overfitting, especialmente para graus mais elevados. Para tentar remediar a situação, algumas ações a serem tomadas seriam a de fazer uma nova análise exploratória da base de dados, procurando quais das variáveis são mais significativas para o valor da taxaa de mortalidade de cada municipalidade, com o intuito de simplificar a base de dados. Outra possibilidade seria a de obter novos dados, ou de censos mais recentes caso estejam disponíveis, ou de censos mais antigos.

# %% [markdown]
# 4. (1 point) Plot the cost function vs. number of epochs in the training/validation set and analyze the model.

# %% [markdown]
# ## 4. Função de custo x Número de épocas

# %%
params, cost = stochastic_gradient_descent(data_train, learning_rate = 0.001, batch_size=10, ephocs=100)

plt.figure(figsize=(10,5))
plt.scatter(np.arange(0,len(cost)), cost)
plt.show()

print(f"Cost after {len(cost)} iterations: {cost[len(cost)-1]}")
# Out:
# Cost after 13900 iterations: 0.6932543951922926

# %% [markdown]
# ### 4.1 Conclusões
#
# Observando o gráfico de função de custo x número de épocas de treinamento, percebemos que o valor do custo em cada iteração se inicia com uma queda pronunciada da funcção de custo, mas com uma flutuação de valor ainda pronunciada, e temos que o valor do custo e sua flutuação diminuem em cada iteração, tendendo a uma estabilização. Como o custo é determinado como o valor da função de perda, temos que, para cada iteração, o modelo se torna mais preciso para aquele conjunto de dados.
#
# Com temos como intenção que o gráfico se estabilize mais rapidamente, ou seja, a flutuação dos valores da função de custo diminuam, seria necessário uma melhor análise exploratória dos dados utilizados, para que os valores de cada variável seja mais significativo para a redução, uma vez que features com valores muito díspares e pouco significado para o problema podem acabar prejudicando a performance do modelo.

# %% [markdown]
# ## Deadline
#
# Monday, October 11th 11:59 pm.
#
# Penalty policy for late submission: You are not encouraged to submit your assignment after due date. However, in case you did, your grade will be penalized as follows:
# - October 12th 11:59 pm : grade * 0.75
# - October 13th 11:59 pm : grade * 0.5
# - October 14th 11:59 pm : grade * 0.25

# %% [markdown]
# ## Submission
#
# On Google Classroom, submit your Jupyter Notebook (in Portuguese or English).
#
# **This activity is NOT individual, it must be done in pairs (two-person group).**
